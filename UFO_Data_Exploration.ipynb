# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
ufo = pd.read_csv('nuforc_reports.csv')

# %%
ufo_clean = ufo.drop(columns = ['summary', 'duration', 'report_link', 'text'])

# %%
ufo_clean.head()
# Out:
#                city state            date_time     shape  \
# 0             Salem    OR                  NaN      disk
# 1         Ellsworth    ME                  NaN  teardrop
# 2       San Antonio    TX  2017-01-25T20:45:00     light
# 3  Port Saint Lucie    FL  2017-02-24T20:45:00    circle
# 4         Whitefish    MT  2017-02-22T21:00:00     light
#
#                                                stats               posted  \
# 0  Occurred : 8/15/1950 14:00  (Entered as : 08/1...                  NaN
# 1  Occurred : 8/15/1967 21:30  (Entered as : 08/0...                  NaN
# 2  Occurred : 1/25/2017 20:45  (Entered as : 01/2...  2017-01-26T00:00:00
# 3  Occurred : 2/24/2017 20:45  (Entered as : 02/2...  2017-03-10T00:00:00
# 4  Occurred : 2/22/2017 21:00  (Entered as : 02/2...  2017-03-10T00:00:00
#
#    city_latitude  city_longitude
# 0      44.941247     -123.004235
# 1      44.651300      -68.450700
# 2      29.488866      -98.475240
# 3      27.285686      -80.363444
# ...

# %%
ufo_clean.dtypes
# Out:
# city               object
# state              object
# date_time          object
# shape              object
# stats              object
# posted             object
# city_latitude     float64
# city_longitude    float64
# dtype: object

# %%
ufo_clean['shape'].value_counts()
# Out:
# light        22761
# circle       11499
# triangle     10488
# fireball      8653
# unknown       7879
# other         7724
# sphere        7362
# disk          7005
# oval          5033
# formation     3456
# changing      2715
# cigar         2679
# flash         1963
# rectangle     1848
# cylinder      1725
# diamond       1650
# chevron       1294
# teardrop      1013
# egg           1004
# cone           468
# cross          344
# delta            8
# crescent         2
# round            2
# changed          1
# dome             1
# pyramid          1
# flare            1
# hexagon          1
# Name: shape, dtype: int64

# %%
ufo_clean['city'].value_counts()
# Out:
# New York                                                        747
# Seattle                                                         709
# Phoenix                                                         672
# Las Vegas                                                       553
# Portland                                                        539
# Los Angeles                                                     477
# San Diego                                                       469
# Houston                                                         405
# Chicago                                                         393
# Tucson                                                          350
# Miami                                                           327
# Orlando                                                         323
# Albuquerque                                                     312
# Vancouver                                                       309
# ...

# %%
# Do we want to include foreign locations?
